# %% [markdown]
# # Load Excel print CSV

# %%
import numpy as np
import pandas as pd
import csv

# %%
df = pd.read_excel('Base Diploma en Gestión de Proyectos Arequipa.xlsx', index_col=None)

# %%
df
# Out:
#                                       producto programa  \
# 0   DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 1   DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 2   DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 3   DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 4   DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 5   DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 6   DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 7   DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 8   DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 9   DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 10  DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 11  DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 12  DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 13  DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 14  DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# 15  DIPLOMA EN GESTIÓN DE PROYECTOS - AREQUIPA  DIPLOMA
# ...

# %%
# evaluation_output_dataframe = pd.DataFrame(evaluation_output, columns=['uuid', 'probability'])
evaluation_output_csv = df.to_csv('prueba.csv', quoting=csv.QUOTE_ALL)
